# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")

# %%
class Database:
    """Base database class providing common database operations."""

    def __init__(self) -> None:
        """Initialize an empty DataFrame."""
        self._df = (
            pd.DataFrame()
        )  # Changed from __df to _df (protected instead of private)

    def get_number_of_records(self) -> int:
        """Return the number of records in the database.
        Returns:
            int: Number of records
        """
        return self._df.shape[0]

    @property
    def shape(self) -> tuple[int, int]:
        """Return the shape of the database (rows, columns).
        Returns:
            tuple: (number of rows, number of columns)
        """
        return self._df.shape

    @property
    def info(self):
        return self._df.info()

    def get_dataframe(self):
        return self._df

# %%
class DatabaseIPL(Database):
    """Database class specialized for IPL cricket data."""

    def __init__(self, csv_files: list[str]) -> None:  # Changed list[int] to list[str]
        """Initialize the database by loading IPL data from CSV files.
        Args:
            csv_files: List of paths to CSV files containing IPL data
        """
        super().__init__()  # Initialize parent class
        for file in csv_files:
            if not os.path.exists(file):
                raise FileNotFoundError(f"CSV file not found: {file}")
            df = pd.read_csv(file)
            self._df = pd.concat([self._df, df], ignore_index=True)

        self._create_city_col()


    def get_all_players(self) -> list[str]:
        players = (
            list(self._df.striker.unique())
            + list(self._df.bowler.unique())
            + list(self._df.fielder.unique())
        )
        return players

    def get_player_count(self) -> int:
        return len(self.get_all_players())

    def get_players_per_season(self):
        df = self._df.groupby(by="season", as_index=False)

# %%
file_paths = [
        f"../data/cricketData/ipl_{year}_deliveries.csv" for year in range(2022, 2025)
    ]

try:
    db = DatabaseIPL(file_paths)
    print(f"Number of records: {db.get_number_of_records():,d}")
    print(f"Database shape: {db.shape}")
    print(f"\Database Info: {db.info}")
    print(f"Database All Players: {db.get_all_players()}")
    print(f"Number Of total Players: {db.get_player_count()}")
except FileNotFoundError as e:
    print(f"Error loading data: {e}")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Number of records: 52,351
# Database shape: (52351, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52351 entries, 0 to 52350
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          52351 non-null  int64
#  1   season            52351 non-null  int64
#  2   match_no          52351 non-null  int64
#  3   date              52351 non-null  object
#  4   venue             52351 non-null  object
#  5   batting_team      52351 non-null  object
#  6   bowling_team      52351 non-null  object
#  7   innings           52351 non-null  int64
#  8   over              52351 non-null  float64
#  9   striker           52351 non-null  object
#  10  bowler            52351 non-null  object
#  11  runs_of_bat       52351 non-null  int64
#  12  extras            52351 non-null  int64
#  13  wide              52351 non-null  int64
#  14  legbyes           52351 non-null  int64
#  15  byes              52351 non-null  int64
#  16  noballs           52351 non-null  int64
#  17  wicket_type       2679 non-null   object
#  18  player_dismissed  2673 non-null   object
#  19  fielder           2116 non-null   object
#  20  city              52351 non-null  object
# dtypes: float64(1), int64(10), object(10)
# memory usage: 8.4+ MB
# \Database Info: None
# Database All Players: ['Gaikwad', 'Uthappa', 'Conway', 'Rayudu', 'Jadeja', 'Shivam Dube', 'Dhoni', 'Rahane', 'Venkatesh Iyer', 'Nitish Rana', 'Shreyas Iyer', 'Billings', 'Jackson', 'Rohit', 'Ishan Kishan', 'Anmolpreet Singh', 'Tilak Varma', 'Pollard', 'Tim David', 'Daniel Sams', 'Prithvi Shaw', 'Seifert', 'Mandeep', 'Pant', 'Lalit Yadav', 'Powell', 'Thakur', 'Axar', 'du Plessis', 'Anuj Rawat', 'Kohli', 'Karthik', 'Mayank', 'Dhawan', 'Rajapaksa', 'Livingstone', 'Raj Bawa', 'Shahrukh Khan', 'Odean Smith', 'Rahul', 'Lewis', 'de Kock', 'Manish Pandey', 'Hooda', 'Ayush Badoni', 'Krunal Pandya', 'Chameera', 'Shubman Gill', 'Shankar', 'Wade', 'Hardik Pandya', 'Miller', 'Rahul Tewatia', 'Abhinav Manohar', 'Buttler', 'Jaiswal', 'Samson', 'Padikkal', 'Hetmyer', 'Riyan Parag', 'Coulter-Nile', 'Williamson', 'Abhishek Sharma', 'Tripathi', 'Pooran', 'Markram', 'Abdul Samad', 'Shepherd', 'Washington Sundar', 'Bhuvneshwar', 'Narine', 'Russell', 'Southee', 'Umesh Yadav', 'Chakaravarthy', 'Rutherford', 'Willey', 'Shahbaz Ahmed', 'Hasaranga', 'Harshal Patel', 'Moeen Ali', 'Pretorius', 'Dwayne Bravo', 'Harpreet Brar', 'Rahul Chahar', 'Rabada', 'Arshdeep Singh', 'Ashwin', 'Navdeep Saini', 'Boult', 'Murugan Ashwin', 'Bumrah', 'Rashid Khan', 'Kuldeep Yadav', 'Khaleel Ahmed', 'Mustafizur', 'Jitesh Sharma', 'Vaibhav Arora', 'Jordan', 'Mukesh Choudhary', 'Holder', 'Umran Malik', 'Brevis', 'Suryakumar Yadav', 'Cummins', 'Warner', 'Sarfaraz Khan', 'Bairstow', 'Sai Sudharsan', 'Ramandeep Singh', 'Unadkat', 'Maxwell', 'Rasikh Salam', 'van der Dussen', 'Gowtham', 'Stoinis', 'Avesh Khan', 'Prabhudessai', 'Akash Deep', 'Siraj', 'Hazlewood', 'Tymal Mills', 'Neesham', 'Prasidh', 'Chahal', 'Kuldeep Sen', 'Finch', 'Aman Hakim Khan', 'Fabian Allen', 'Mitchell Marsh', 'Prabhsimran', 'W Saha', 'Alzarri Joseph', 'Karun Nair', 'Shivam Mavi', 'Ravi Bishnoi', 'Nathan Ellis', 'Hrithik Shokeen', 'Santner', 'Ferguson', 'Yash Dayal', 'Rinku Singh', 'Daryl Mitchell', 'Rajat Patidar', 'Shashank Singh', 'Marco Jansen', 'Indrajith', 'Harshit Rana', 'Mohsin Khan', 'Rishi Dhawan', 'Lomror', 'Sangwan', 'Simarjeet Singh', 'M Theekshana', 'Abbott', 'Shreyas Gopal', 'Kartik Tyagi', 'Anukul Roy', 'J Suchith', 'Fazalhaq Farooqi', 'Srikar Bharat', 'Ripal Patel', 'Nortje', 'Kumar Kartikeya', 'Meredith', 'Karan Sharma', 'Tristan Stubbs', 'N Jagadeesan', 'Priyam Garg', 'Sanjay Yadav', 'Abhijeet Tomar', 'Prerak Mankad', 'Vohra', 'Obed McCoy', 'Stokes', 'Saha', 'Raza', 'Sam Curran', 'Gurbaz', 'Mayers', 'Rossouw', 'Sakariya', 'Mukesh Kumar', 'Harry Brook', 'Glenn Phillips', 'Adil Rashid', 'Green', 'Nehal Wadhera', 'Arshad Khan', 'Mark Wood', 'Abishek Porel', 'Dhruv Jurel', 'M Bracewell', 'Karn Sharma', 'Chawla', 'Short', 'Mohit Rathee', 'Yash Dhull', 'Zampa', 'Klaasen', 'Yudhvir Singh', 'Atharva Taide', 'Harpreet Singh', 'Parnell', 'Markande', 'Roy', 'Litton Das', 'Philip Salt', 'Jofra Archer', 'Vijaykumar Vyshak', 'Abdul Basith', 'Wiese', 'Ishant', 'Arjun Tendulkar', 'Behrendorff', 'Akeal Hosein', 'Mishra', 'Naveen-ul-Haq', 'Sandeep Sharma', 'Swapnil Singh', 'Kedar Jadhav', 'Chahar', 'Tushar Deshpande', 'Vishnu Vinod', 'Noor Ahmad', 'Praveen Dubey', 'Root', 'KM Asif', 'Shanaka', 'Shami', 'Mohit Sharma', 'Sanvir Singh', 'Vivrant Sharma', 'Darshan Nalkande', 'Kartikeya', 'Ravindra', 'Mitchell', 'Shai Hope', 'Bhui', 'Sumit Kumar', 'Starc', 'Azmatullah', 'Naman Dhir', 'Gerald Coetzee', 'Shams Mulani', 'Sameer Rizvi', 'Spencer Johnson', 'Head', 'Akash Madhwal', 'Shubham Dubey', 'Mayank Dagar', 'Topley', 'Angkrish Raghuvanshi', 'Ashutosh Sharma', 'Nitish Reddy', 'Saurav Chauhan', 'Kushagra', 'J Richardson', 'Sharath BR', 'Will Jacks', 'Fraser-McGurk', 'Tanush Kotian', 'Maharaj', 'Nabi', 'Sai Kishore', 'Wood', 'Williams', 'Arshin Kulkarni', 'Turner', 'Manav Suthar', 'Richard Gleeson', 'Gulbadin', 'Ferreira', 'Anshul Kamboj', 'Kohler-Cadmore', 'Shivam Singh', 'V Viyaskanth', 'Umesh Yadav', 'Shivam Mavi', 'Chakaravarthy', 'Narine', 'Russell', 'Tushar Deshpande', 'Milne', 'Santner', 'Dwayne Bravo', 'S ...
# Number Of total Players: 873

# %%
df = db.get_dataframe()

# %%
df
# Out:
#        match_id  season  match_no          date  \
# 0        202201    2022         1  Mar 26, 2022
# 1        202201    2022         1  Mar 26, 2022
# 2        202201    2022         1  Mar 26, 2022
# 3        202201    2022         1  Mar 26, 2022
# 4        202201    2022         1  Mar 26, 2022
# ...         ...     ...       ...           ...
# 52346    202474    2024        74  May 26, 2024
# 52347    202474    2024        74  May 26, 2024
# 52348    202474    2024        74  May 26, 2024
# 52349    202474    2024        74  May 26, 2024
# 52350    202474    2024        74  May 26, 2024
#
#                                  venue batting_team bowling_team  innings  \
# 0             Wankhede Stadium, Mumbai          CSK          KKR        1
# 1             Wankhede Stadium, Mumbai          CSK          KKR        1
# 2             Wankhede Stadium, Mumbai          CSK          KKR        1
# 3             Wankhede Stadium, Mumbai          CSK          KKR        1
# 4             Wankhede Stadium, Mumbai          CSK          KKR        1
# ...                                ...          ...          ...      ...
# 52346  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 52347  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 52348  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 52349  MA Chidambaram Stadium, Chennai          KKR          SRH        2
# 52350  MA Chidambaram Stadium, Chennai          KKR          SRH        2
#
#        over         striker  ... runs_of_bat  extras  wide  legbyes  byes  \
# 0       0.1         Gaikwad  ...           0       1     0        0     0
# 1       0.1         Gaikwad  ...           0       0     0        0     0
# 2       0.2         Gaikwad  ...           0       1     1        0     0
# 3       0.2         Gaikwad  ...           0       0     0        0     0
# 4       0.3         Gaikwad  ...           0       0     0        0     0
# ...     ...             ...  ...         ...     ...   ...      ...   ...
# 52346   9.5    Shreyas Iyer  ...           1       0     0        0     0
# 52347   9.6  Venkatesh Iyer  ...           1       0     0        0     0
# 52348  10.1  Venkatesh Iyer  ...           1       0     0        0     0
# 52349  10.2    Shreyas Iyer  ...           1       0     0        0     0
# 52350  10.3  Venkatesh Iyer  ...           1       0     0        0     0
#
#        noballs  wicket_type player_dismissed      fielder      city
# 0            1          NaN              NaN          NaN    Mumbai
# 1            0          NaN              NaN          NaN    Mumbai
# 2            0          NaN              NaN          NaN    Mumbai
# 3            0          NaN              NaN          NaN    Mumbai
# 4            0       caught          Gaikwad  Nitish Rana    Mumbai
# ...        ...          ...              ...          ...       ...
# 52346        0          NaN              NaN          NaN   Chennai
# 52347        0          NaN              NaN          NaN   Chennai
# 52348        0          NaN              NaN          NaN   Chennai
# 52349        0          NaN              NaN          NaN   Chennai
# 52350        0          NaN              NaN          NaN   Chennai
#
# [52351 rows x 21 columns]

# %%
df.season.unique()
# Out:
# array([2022, 2023, 2024])

# %%
len(df.striker.unique())
# Out:
# 277

# %%
len(df.bowler.unique())
# Out:
# 215

# %%
len(df.fielder.unique())
# Out:
# 381

# %%
players = set(list(df.striker.unique()) + list(df.bowler.unique()))

len(players)
# Out:
# 311

# %%
players
# Out:
# {'Aaron',
#  'Abbott',
#  'Abdul Basith',
#  'Abdul Samad',
#  'Abhijeet Tomar',
#  'Abhinav Manohar',
#  'Abhishek Sharma',
#  'Abishek Porel',
#  'Adil Rashid',
#  'Akash Deep',
#  'Akash Madhwal',
#  'Akash Singh',
#  'Akeal Hosein',
#  'Alzarri Joseph',
#  'Aman Hakim Khan',
#  'Angkrish Raghuvanshi',
#  'Anmolpreet Singh',
#  'Anshul Kamboj',
#  'Anuj Rawat',
#  'Anukul Roy',
#  'Arjun Tendulkar',
#  'Arshad Khan',
#  'Arshdeep Singh',
#  'Arshin Kulkarni',
#  'Ashutosh Sharma',
#  'Ashwin',
#  'Atharva Taide',
#  'Avesh Khan',
#  'Axar',
#  'Ayush Badoni',
#  'Azmatullah',
#  'Bairstow',
#  'Basil Thampi',
#  'Behrendorff',
#  'Bhui',
#  'Bhuvneshwar',
#  'Billings',
#  'Boult',
#  'Brevis',
#  'Bumrah',
#  'Buttler',
#  'Chahal',
#  'Chahar',
#  'Chakaravarthy',
#  'Chameera',
#  'Chawla',
#  'Chetan Sakariya',
#  'Conway',
#  'Coulter-Nile',
#  'Cummins',
#  'Daniel Sams',
#  'Darshan Nalkande',
#  'Daryl Mitchell',
#  'Dhawan',
#  'Dhoni',
#  'Dhruv Jurel',
#  'Dwayne Bravo',
#  'Fabian Allen',
#  'Fazalhaq Farooqi',
#  'Ferguson',
#  'Ferreira',
#  'Finch',
#  'Fraser-McGurk',
#  'Gaikwad',
#  'Gerald Coetzee',
#  'Glenn Phillips',
#  'Gowtham',
#  'Green',
#  'Gulbadin',
#  'Gurbaz',
#  'Gurnoor Brar',
#  'Hardik Pandya',
#  'Harpreet Brar',
#  'Harpreet Singh',
#  'Harry Brook',
#  'Harshal Patel',
#  'Harshit Rana',
#  'Hasaranga',
#  'Hazlewood',
#  'Head',
#  'Hetmyer',
#  'Himanshu Sharma',
#  'Holder',
#  'Hooda',
#  'Hrithik Shokeen',
#  'Indrajith',
#  'Ishan Kishan',
#  'Ishant',
#  'J Richardson',
#  'J Suchith',
#  'Jackson',
#  'Jadeja',
#  'Jaiswal',
#  'Jansen',
#  'Jayant Yadav',
#  'Jitesh Sharma',
#  'Jofra Archer',
#  'Jordan',
#  'Joshua Little',
#  'K Nagarkoti',
#  'KM Asif',
#  'Karan Sharma',
#  'Karn Sharma',
#  'Karthik',
#  'Kartik Tyagi',
#  'Kartikeya',
#  'Karun Nair',
#  'Kaverappa',
#  'Kedar Jadhav',
#  'Khaleel Ahmed',
#  'Khejroliya',
#  'Klaasen',
#  'Kohler-Cadmore',
#  'Kohli',
#  'Krunal Pandya',
#  'Kuldeep Sen',
#  'Kuldeep Yadav',
#  'Kuldip Yadav',
#  'Kumar Kartikeya',
#  'Kushagra',
#  'Kwena Maphaka',
#  'Lalit Yadav',
#  'Lewis',
#  'Litton Das',
#  'Livingstone',
#  'Lomror',
#  'M Bracewell',
#  'M Siddharth',
#  'M Theekshana',
#  'Magala',
#  'Maharaj',
#  'Manav Suthar',
#  'Mandeep',
#  'Manish Pandey',
#  'Marco Jansen',
#  'Mark Wood',
#  'Markande',
#  'Markram',
#  'Matheesha Pathirana',
#  'Matt Henry',
#  'Maxwell',
#  'Mayank',
#  'Mayank Dagar',
#  'Mayank Yadav',
#  'Mayers',
#  'Meredith',
#  'Miller',
#  'Milne',
#  'Mishra',
#  'Mitchell',
#  'Mitchell Marsh',
#  'Moeen Ali',
#  'Mohit Rathee',
#  'Mohit Sharma',
#  'Mohsin Khan',
#  'Mukesh Choudhary',
#  'Mukesh Kumar',
#  'Murugan Ashwin',
#  'Mustafizur',
#  'N Jagadeesan',
#  'N Thushara',
#  'Nabi',
#  'Naman Dhir',
#  'Nandre Burger',
#  'Narine',
#  'Nathan Ellis',
#  'Navdeep Saini',
#  'Naveen-ul-Haq',
#  'Neesham',
#  'Nehal Wadhera',
#  'Nitish Rana',
#  'Nitish Reddy',
#  'Noor Ahmad',
#  'Nortje',
#  'Obed McCoy',
#  'Odean Smith',
#  'Padikkal',
#  'Pant',
#  'Parnell',
#  'Pathirana',
#  'Philip Salt',
#  'Pollard',
#  'Pooran',
#  'Powell',
#  'Prabhsimran',
#  'Prabhudessai',
#  'Prasidh',
#  'Praveen Dubey',
#  'Prerak Mankad',
#  'Pretorius',
#  'Prithvi Shaw',
#  'Priyam Garg',
#  'RS Hangargekar',
#  'Rabada',
#  'Raghav Goyal',
#  'Rahane',
#  'Rahul',
#  'Rahul Chahar',
#  'Rahul Tewatia',
#  'Raj Bawa',
#  'Rajapaksa',
#  'Rajat Patidar',
#  'Ramandeep Singh',
#  'Rashid Khan',
#  'Rasikh Salam',
#  'Ravi Bishnoi',
#  'Ravindra',
#  'Rayudu',
#  'Raza',
#  'Richard Gleeson',
#  'Rinku Singh',
#  'Ripal Patel',
#  'Rishi Dhawan',
#  'Riyan Parag',
#  'Rohit',
#  'Root',
#  'Rossouw',
#  'Roy',
#  'Russell',
#  'Rutherford',
#  'S Kaul',
#  'Saha',
#  'Sai Kishore',
#  'Sai Sudharsan',
#  'Sakariya',
#  'Sam Curran',
#  'Sameer Rizvi',
#  'Samson',
#  'Sandeep Sharma',
#  'Sangwan',
#  'Sanjay Yadav',
#  'Santner',
#  'Sanvir Singh',
#  'Sarfaraz Khan',
#  'Saurav Chauhan',
#  'Seifert',
#  'Shahbaz Ahmed',
#  'Shahrukh Khan',
#  'Shai Hope',
#  'Shamar Joseph',
#  'Shami',
#  'Shams Mulani',
#  'Shanaka',
#  'Shankar',
#  'Sharath BR',
#  'Shashank Singh',
#  'Shepherd',
#  'Shivam Dube',
#  'Shivam Mavi',
#  'Shivam Singh',
#  'Short',
#  'Shreyas Gopal',
#  'Shreyas Iyer',
#  'Shubham Dubey',
#  'Shubman Gill',
#  'Simarjeet Singh',
#  'Siraj',
#  'Solanki',
#  'Southee',
#  'Spencer Johnson',
#  'Srikar Bharat',
#  'Starc',
#  'Stoinis',
#  'Stokes',
#  'Sumit Kumar',
#  'Suryakumar Yadav',
#  'Suyash Sharma',
#  'Swapnil Singh',
#  'T Natarajan',
#  'Tanush Kotian',
#  'Thakur',
#  'Theekshana',
#  'Tilak Varma',
#  'Tim David',
#  'Topley',
#  'Tripathi',
#  'Tristan Stubbs',
#  'Turner',
#  'Tushar Deshpande',
#  'Tye',
#  'Tymal Mills',
#  'Umesh Yadav',
#  'Umran Malik',
#  'Unadkat',
#  'Uthappa',
#  'V Viyaskanth',
#  'Vaibhav Arora',
#  'Venkatesh Iyer',
#  'Vijaykumar Vyshak',
#  'Vishnu Vinod',
#  'Vivrant Sharma',
#  'Vohra',
#  'W Saha',
#  'Wade',
#  'Warner',
#  'Warrier',
#  'Washington Sundar',
#  'Wiese',
#  'Will Jacks',
#  'Willey',
#  'Williams',
#  'Williamson',
#  'Wood',
#  'Yash Dayal',
#  'Yash Dhull',
#  'Yash Thakur',
#  'Yudhvir Singh',
#  'Zampa',
#  'de Kock',
#  'du Plessis',
#  'van der Dussen'}

# %%
df.groupby(by="venue")["match_id"].nunique().sort_values(ascending=False)
# Out:
# venue
# Wankhede Stadium, Mumbai                                                          35
# Dr DY Patil Sports Academy, Mumbai                                                20
# Narendra Modi Stadium, Ahmedabad                                                  19
# MA Chidambaram Stadium, Chennai                                                   17
# Eden Gardens, Kolkata                                                             16
# Brabourne Stadium, Mumbai                                                         16
# M.Chinnaswamy Stadium, Bengaluru                                                  14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow             14
# Maharashtra Cricket Association Stadium, Pune                                     13
# Rajiv Gandhi International Stadium, Hyderabad                                     13
# Arun Jaitley Stadium, Delhi                                                       12
# Sawai Mansingh Stadium, Jaipur                                                    10
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur, Chandigarh     5
# Punjab Cricket Association IS Bindra Stadium, Mohali                               5
# Himachal Pradesh Cricket Association Stadium, Dharamsala                           3
# Barsapara Cricket Stadium, Guwahati                                                3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam                 2
# Name: match_id, dtype: int64

# %%
df_group = df.groupby(by=["season","venue"],as_index=False)["match_id"].nunique()
df_group.sort_values("match_id", ascending=False, inplace=True)
df_group
# Out:
#     season                                              venue  match_id
# 5     2022                           Wankhede Stadium, Mumbai        21
# 1     2022                 Dr DY Patil Sports Academy, Mumbai        20
# 0     2022                          Brabourne Stadium, Mumbai        16
# 3     2022      Maharashtra Cricket Association Stadium, Pune        13
# 25    2024                    MA Chidambaram Stadium, Chennai         9
# 13    2023                   Narendra Modi Stadium, Ahmedabad         9
# 12    2023                    MA Chidambaram Stadium, Chennai         8
# 27    2024                   Narendra Modi Stadium, Ahmedabad         8
# 24    2024                   M.Chinnaswamy Stadium, Bengaluru         7
# 22    2024                              Eden Gardens, Kolkata         7
# 20    2024  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...         7
# 17    2023                           Wankhede Stadium, Mumbai         7
# 15    2023      Rajiv Gandhi International Stadium, Hyderabad         7
# 11    2023                   M.Chinnaswamy Stadium, Bengaluru         7
# 9     2023                              Eden Gardens, Kolkata         7
# 6     2023                        Arun Jaitley Stadium, Delhi         7
# 8     2023  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...         7
# 30    2024                           Wankhede Stadium, Mumbai         7
# 28    2024      Rajiv Gandhi International Stadium, Hyderabad         6
# 18    2024                        Arun Jaitley Stadium, Delhi         5
# 16    2023                     Sawai Mansingh Stadium, Jaipur         5
# 14    2023  Punjab Cricket Association IS Bindra Stadium, ...         5
# 26    2024  Maharaja Yadavindra Singh International Cricke...         5
# 29    2024                     Sawai Mansingh Stadium, Jaipur         5
# 21    2024  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...         2
# 23    2024  Himachal Pradesh Cricket Association Stadium, ...         2
# 4     2022                   Narendra Modi Stadium, Ahmedabad         2
# 2     2022                              Eden Gardens, Kolkata         2
# 7     2023                Barsapara Cricket Stadium, Guwahati         2
# 19    2024                Barsapara Cricket Stadium, Guwahati         1
# 10    2023  Himachal Pradesh Cricket Association Stadium, ...         1

# %%
title = f"Matches Per Venue From {df_group.season.min()} to {df_group.season.max()}"
title
# Out:
# 'Matches Per Venue From 2022 to 2024'

# %%
df_group[df_group.venue == "Wankhede Stadium, Mumbai"]
# Out:
#     season                     venue  match_id
# 5     2022  Wankhede Stadium, Mumbai        21
# 17    2023  Wankhede Stadium, Mumbai         7
# 30    2024  Wankhede Stadium, Mumbai         7
